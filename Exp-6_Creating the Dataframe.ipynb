# %%
#Aim: To create the dataframe

# %%
#Name: Vrushali Uphade
#Roll no: 76
#Sec: A
#Subject: ET-1
#Date:25/8/25

# %%
#importing pandas library
import pandas as pd

# %%
#Creating Dataframe
df=pd.DataFrame([[10,20,34,55],[30,20,10,90],[20,70,80,90]],
columns=["CD","DBMS","DSS","CAO"])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    20   34   55
# 1  30    20   10   90
# 2  20    70   80   90

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df2=pd.DataFrame([[5,6,7,8,9]],columns=["CD","DBMS","DSS","CAO","DM"])

# %%
df.ndim
# Out:
# 2

# %%
df3 = pd.concat([df, df2])

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO   DM
# 0  10    20   34   55  NaN
# 1  30    20   10   90  NaN
# 2  20    70   80   90  NaN
# 0   5     6    7    8  9.0

# %% [markdown]
# # Adding rows in the DataFrame

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns=["CD","DBMS","DSS","CAO"])

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    20   34   55
# 1  30    20   10   90
# 2  20    70   80   90
# 3   5     6    7    8

# %% [markdown]
# # Adding Attribute(Columns)in the DataFrame name DM

# %%
df3["DM"]=[10,20,30,44]

# %%
df3
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    20   34   55  10
# 1  30    20   10   90  20
# 2  20    70   80   90  30
# 3   5     6    7    8  44

# %% [markdown]
# # Deleting Record From DataFrame

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    20   34   55  10
# 2  20    70   80   90  30
# 3   5     6    7    8  44

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    20   34   55
# 1  30    20   10   90
# 2  20    70   80   90
# 3   5     6    7    8

# %% [markdown]
# # Finding Mean Of DSS

# %%
print("Mean of DSS:",df5["DSS"].mean())
# Out:
# Mean of DSS: 32.75

# %%
print("Median of DSS:",df5["DSS"].median())
# Out:
# Median of DSS: 22.0

# %%
print("Mode of DSS:",df5["DSS"].mode())
# Out:
# Mode of DSS: 0     7
# 1    10
# 2    34
# 3    80
# Name: DSS, dtype: int64

# %%
print("Min of DSS:",df5["DSS"].min())
# Out:
# Min of DSS: 7

# %%
print("Max of DSS:",df5["DSS"].max())
# Out:
# Max of DSS: 80

# %%
Name=["vrushali","radhika","raghav"]
Name
# Out:
# ['vrushali', 'radhika', 'raghav']
